# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("/content/Testing.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              9      120             72             22       56  20.8
# 1              1       71             62              0        0  21.8
# 2              8       74             70             40       49  35.3
# 3              5       88             78             30        0  27.6
# 4             10      115             98              0        0  24.0
# ..           ...      ...            ...            ...      ...   ...
# 303           10      101             76             48      180  32.9
# 304            2      122             70             27        0  36.8
# 305            5      121             72             23      112  26.2
# 306            1      126             60              0        0  30.1
# 307            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.733   48        0
# 1                       0.416   26        0
# 2                       0.705   39        0
# 3                       0.258   37        0
# 4                       1.022   34        0
# ..                        ...  ...      ...
# 303                     0.171   63        0
# 304                     0.340   27        0
# 305                     0.245   30        0
# 306                     0.349   47        1
# 307                     0.315   23        0
#
# [308 rows x 9 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9      120             72             22       56  20.8
# 1            1       71             62              0        0  21.8
# 2            8       74             70             40       49  35.3
# 3            5       88             78             30        0  27.6
# 4           10      115             98              0        0  24.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.733   48        0
# 1                     0.416   26        0
# 2                     0.705   39        0
# 3                     0.258   37        0
# 4                     1.022   34        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               308 non-null    int64
#  1   Glucose                   308 non-null    int64
#  2   BloodPressure             308 non-null    int64
#  3   SkinThickness             308 non-null    int64
#  4   Insulin                   308 non-null    int64
#  5   BMI                       308 non-null    float64
#  6   DiabetesPedigreeFunction  308 non-null    float64
#  7   Age                       308 non-null    int64
#  8   Outcome                   308 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 21.8 KB

# %%
df['Outcome'].unique()
# Out:
# array([0, 1])

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (308, 9)

# %%
df.size
# Out:
# 2772

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   308.000000  308.000000     308.000000     308.000000  308.000000
# mean      3.863636  119.983766      69.503247      20.694805   77.724026
# std       3.381437   31.186260      19.555067      16.298250  106.528025
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   97.750000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   17.000000
# 75%       6.000000  136.000000      80.000000      32.000000  127.750000
# max      13.000000  199.000000     114.000000      99.000000  600.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  308.000000                308.000000  308.000000  308.000000
# mean    31.865909                  0.445042   33.730519    0.301948
# std      7.427594                  0.297660   12.208374    0.459850
# min      0.000000                  0.085000   21.000000    0.000000
# 25%     27.400000                  0.228250   24.000000    0.000000
# 50%     32.000000                  0.348000   29.000000    0.000000
# 75%     36.425000                  0.600000   42.000000    1.000000
# max     57.300000                  1.699000   70.000000    1.000000

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.038095       0.166163      -0.125704
# Glucose                      0.038095  1.000000       0.221150       0.113453
# BloodPressure                0.166163  0.221150       1.000000       0.242019
# SkinThickness               -0.125704  0.113453       0.242019       1.000000
# Insulin                     -0.130021  0.309074       0.094094       0.413319
# BMI                         -0.077651  0.195295       0.322599       0.417625
# DiabetesPedigreeFunction    -0.004082  0.086689       0.129540       0.207632
# Age                          0.550256  0.225663       0.291844      -0.080434
# Outcome                      0.206719  0.479823       0.067085       0.100563
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.130021 -0.077651                 -0.004082
# Glucose                   0.309074  0.195295                  0.086689
# BloodPressure             0.094094  0.322599                  0.129540
# SkinThickness             0.413319  0.417625                  0.207632
# Insulin                   1.000000  0.199884                  0.153375
# BMI                       0.199884  1.000000                  0.183257
# DiabetesPedigreeFunction  0.153375  0.183257                  1.000000
# Age                      -0.118570 -0.004538                  0.036720
# Outcome                   0.136689  0.253266                  0.153684
#
#                                Age   Outcome
# Pregnancies               0.550256  0.206719
# Glucose                   0.225663  0.479823
# BloodPressure             0.291844  0.067085
# SkinThickness            -0.080434  0.100563
# Insulin                  -0.118570  0.136689
# BMI                      -0.004538  0.253266
# DiabetesPedigreeFunction  0.036720  0.153684
# Age                       1.000000  0.262872
# Outcome                   0.262872  1.000000

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9)

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred_train=log_model.predict(x_train)
ypred_test=log_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,ypred_train))
print(accuracy_score(y_test,ypred_test))
# Out:
# 0.8211382113821138
# 0.7580645161290323

# %%
# Out:
# [0.75806452 0.83870968 0.80645161 0.75409836 0.81967213]
# np.float64(0.7953992596509784)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,ypred_test)
# Out:
# array([[42,  6],
#        [ 9,  5]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        48
#            1       0.45      0.36      0.40        14
#
#     accuracy                           0.76        62
#    macro avg       0.64      0.62      0.62        62
# weighted avg       0.74      0.76      0.75        62

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_estimator(log_model, x_test, y_test)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier()
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,ypred_train))
print(accuracy_score(y_test,ypred_test))
# Out:
# 0.8211382113821138
# 0.7580645161290323

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(log_model,x,y,cv=5)
print(scores)
scores.mean()
# Out:
# [0.75806452 0.83870968 0.80645161 0.75409836 0.81967213]
# np.float64(0.7953992596509784)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,ypred_train))
print(accuracy_score(y_test,ypred_test))
# Out:
# 0.8211382113821138
# 0.7580645161290323

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(log_model,x,y,cv=5)
print(scores)
scores.mean()
# Out:
# [0.75806452 0.83870968 0.80645161 0.75409836 0.81967213]
# np.float64(0.7953992596509784)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,ypred_train))
print(accuracy_score(y_test,ypred_test))
# Out:
# 0.8211382113821138
# 0.7580645161290323

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(log_model,x,y,cv=5)
print(scores)
scores.mean()
# Out:
# [0.75806452 0.83870968 0.80645161 0.75409836 0.81967213]
# np.float64(0.7953992596509784)

# %%
from sklearn.svm import SVC

model=SVC()
categorical_cols = x_train.select_dtypes(include='object').columns
x_train = pd.get_dummies(x_train, columns=categorical_cols)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,ypred_train))
print(accuracy_score(y_test,ypred_test))
# Out:
# 0.8211382113821138
# 0.7580645161290323

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(log_model,x,y,cv=5)
print(scores)
scores.mean()
# Out:
# [0.75806452 0.83870968 0.80645161 0.75409836 0.81967213]
# np.float64(0.7953992596509784)

# %%
df=pd.DataFrame({'model':['LR','SVC','RF','DT','KNN'],
                 'Train':[0.82,0.82,0.82,0.82,0.82],
                 'Test':[0.75,0.75,0.75,0.75,0.75],
                 'CV':[0.79,0.79,0.79,0.79,0.79],})
df
# Out:
#   model  Train  Test    CV
# 0    LR   0.82  0.75  0.79
# 1   SVC   0.82  0.75  0.79
# 2    RF   0.82  0.75  0.79
# 3    DT   0.82  0.75  0.79
# 4   KNN   0.82  0.75  0.79
